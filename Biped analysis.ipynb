# %% [markdown]
# # Table of Contents

# %% [markdown]
# * <a href="#All-training-runs-together">Fitness over time for training runs</a>
#
# * <a href="#All-holdout-runs-together">Fitness over time for holdout runs</a>
#
# * <a href="#Final-fitness-prediction---Training-set">Does early fitness predict final fitness? Training set</a>
#
# * <a href="#Final-fitness-prediction---Holdout-set">Does early fitness predict final fitness? Holdout set</a>
#
# * <a href="#Videos---Training-set">Video analysis - Training set</a>
#
# * <a href="#Videos---Holdout-set">Video analysis - Holdout set</a>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # All training runs together

# %%
from glob import glob
from pandas import read_csv

figure(figsize=(12, 7))

for fitness_file in sorted(glob("training-bipeds/*_log.txt")):
    fitness_data = read_csv(fitness_file, sep=" ", names=["generation", "fitness", "dummy"])
    fitness_data.fitness.plot(color="blue")

# %% [markdown]
# # All training runs separately

# %% [markdown]
# Good news! Fitness doesn't flatline.

# %%
from glob import glob
from pandas import read_csv

for fitness_file in sorted(glob("training-bipeds/*_log.txt")):
    fitness_data = read_csv(fitness_file, sep=" ", names=["generation", "fitness", "dummy"])
    figure(figsize=(12, 7))
    title(fitness_file.strip("_log.txt").split("/")[1])
    fitness_data.fitness.plot()
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# # All holdout runs together

# %%
from glob import glob
from pandas import read_csv

figure(figsize=(12, 7))

for fitness_file in sorted(glob("holdout-bipeds/*_log.txt")):
    fitness_data = read_csv(fitness_file, sep=" ", names=["generation", "fitness", "dummy"])
    fitness_data.fitness.plot(color="blue")

# %% [markdown]
# # All holdout runs separately

# %%
from glob import glob
from pandas import read_csv

for fitness_file in sorted(glob("holdout-bipeds/*_log.txt")):
    fitness_data = read_csv(fitness_file, sep=" ", names=["generation", "fitness", "dummy"])
    figure(figsize=(12, 7))
    title(fitness_file.strip("_log.txt").split("/")[1])
    fitness_data.fitness.plot()

# %% [markdown]
# # Can early generation fitness predict the final generation fitness?

# %% [markdown]
# The first generation that early fitness is significantly predictive of final fitness is generation ~150.
#
# We therefore need input from AMT users before generation 150.
#
# We should look at the videos of the early bipeds from the best runs at around generation 50 or 100, and compare them to the bad runs, to see if a human would actually be able to tell which one is more promising.

# %% [markdown]
# ## Final fitness prediction - Training set

# %%
from glob import glob
from pandas import read_csv
data_dfs = []

for fitness_file in sorted(glob("training-bipeds/*_log.txt")):
    fitness_data = read_csv(fitness_file, sep=" ", names=["generation", "fitness", "dummy"])
    del fitness_data["dummy"]
    data_dfs.append(fitness_data)

# %%
from scipy.stats import spearmanr

for early_gen in range(0, 1001, 50):
    early_fitnesses = []
    late_fitnesses = []
    for data_df in data_dfs:
        early_fitnesses.append(data_df.fitness[early_gen])
        late_fitnesses.append(data_df.fitness[2000])
        
    (corr_coeff, pval) = spearmanr(early_fitnesses, late_fitnesses)
    
    figure(figsize=(12, 7))
    title("gen %d vs. 2000, corr coeff = %f, p = %f" % (early_gen, corr_coeff, pval))
    scatter(early_fitnesses, late_fitnesses)
    xlabel("fitness at gen %d" % (early_gen))
    ylabel("fitness at gen 2000")

# %% [markdown]
# ## Final fitness prediction - Holdout set

# %%
from glob import glob
from pandas import read_csv
data_dfs = []

for fitness_file in sorted(glob("holdout-bipeds/*_log.txt")):
    fitness_data = read_csv(fitness_file, sep=" ", names=["generation", "fitness", "dummy"])
    del fitness_data["dummy"]
    data_dfs.append(fitness_data)

# %%
from scipy.stats import spearmanr

for early_gen in range(0, 1001, 50):
    early_fitnesses = []
    late_fitnesses = []
    for data_df in data_dfs:
        early_fitnesses.append(data_df.fitness[early_gen])
        late_fitnesses.append(data_df.fitness[2000])
        
    (corr_coeff, pval) = spearmanr(early_fitnesses, late_fitnesses)
    
    figure(figsize=(12, 7))
    title("gen %d vs. 2000, corr coeff = %f, p = %f" % (early_gen, corr_coeff, pval))
    scatter(early_fitnesses, late_fitnesses)
    xlabel("fitness at gen %d" % (early_gen))
    ylabel("fitness at gen 2000")

# %% [markdown]
# # Biped video analysis

# %% [markdown]
# ## Videos - Training set

# %% [markdown]
# run 16 (final fitness: 210): gen 99 & 149 look promising (are same gait)
#
# run 44 (final fitness: 190): doesn't look promising at all by gen 149
#
# run 11 (final fitness: 180): gen 149 looks fairly promising
#
# run 39 (final fitness: 180): gen 99 & 149 look promising (149 moreso)
#
# run 40 (final fitness: 170): gen 149 looks promising
#
# run 43 (final fitness: 95): doesn't look promising by gen 149
#
# run 37 (final fitness: 65): kinda looks promising (but not really) at gens 99 & 149
#
# run 22 (final fitness: 58): look very promising at gens 99 & 149
#
# run 05 (final fitness: 40): doesn't look promising by gen 149
#
# run 38 (final fitness: 39): doesn't look promising at all by gen 149
#
# the rest of the runs do not look promising at all by gen 149

# %% [markdown]
# ## Videos - Holdout set
