# %%
# %pylab inline
import seaborn as sb
from pandas import read_csv
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
all_data = read_csv("randy-results/all_experiments.csv")
all_data.head(10)
# Out:
#    Evaluation  Cur_Best_Fitness  Exploration_Metric  Clock_Time  Run_Number  \
# 0         500           1.23460           6135.8940         NaN           1
# 1        1000           1.23460           6134.7020         NaN           1
# 2        1500           1.39806           6133.1680         NaN           1
# 3        2000           1.39806           6132.2680         NaN           1
# 4        2500           1.41934           6132.9472         NaN           1
# 5        3000           1.45875           6135.1244         NaN           1
# 6        3500           1.45875           6135.8560         NaN           1
# 7        4000           1.45875           6138.3324         NaN           1
# 8        4500           1.49586           6141.1646         NaN           1
# 9        5000           1.49586           6141.7252         NaN           1
#
#   Domain Selection  Final_Fitness
# 0  Biped   Fitness        5.17964
# 1  Biped   Fitness        5.17964
# ...

# %%
all_data.describe()
# Out:
#            Evaluation  Cur_Best_Fitness  Exploration_Metric    Clock_Time  \
# count  1200600.000000    1200600.000000      1200600.000000  6.003000e+05
# mean    500500.000000        144.209711         3009.575401  1.412998e+09
# std     288819.556368        154.966341         2978.885733  3.249629e+04
# min        500.000000          1.078480            2.639259  1.412966e+09
# 25%     250500.000000          4.881910           33.797374  1.412973e+09
# 50%     500500.000000        185.682000         2908.382806  1.412989e+09
# 75%     750500.000000        259.962000         5967.651050  1.413014e+09
# max    1000500.000000        752.000000         6175.489800  1.413187e+09
#
#            Run_Number   Final_Fitness
# count  1200600.000000  1200600.000000
# mean        50.500000      172.911895
# std         28.866082      192.424890
# min          1.000000        1.685440
# 25%         25.750000        6.193672
# 50%         50.500000      205.676000
# ...

# %%
data_subset_fitnov = all_data[all_data.Selection == "Fitnov"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Domain == "Maze"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Final_Fitness > 500]

figure()
for i, group in data_subset_fitnov.groupby("Run_Number"):
    dataz = (group.Exploration_Metric.values)
    plot(range(len(dataz)), dataz)
    

def moving_average(a, n=100) :
  ret = np.cumsum(a, dtype=float)
  ret[n:] = ret[n:] - ret[:-n]
  return ret[n - 1:] / n

data_subset_fitnov = all_data[all_data.Selection == "Fitnov"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Domain == "Maze"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Final_Fitness < 500]

figure()
for i, group in data_subset_fitnov.groupby("Run_Number"):
    dataz = (group.Exploration_Metric.values)
    plot(range(len(dataz)), dataz)
;
# Out:
# ''

# %%
data_subset_fitnov = all_data[all_data.Selection == "Fitnov"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Domain == "Maze"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Final_Fitness > 500]

figure()
for i, group in data_subset_fitnov.groupby("Run_Number"):
    dataz = (group.Exploration_Metric.values)
    plot(range(len(dataz)), dataz, color="blue")
    

data_subset_fitnov = all_data[all_data.Selection == "Fitnov"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Domain == "Maze"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Final_Fitness < 500]

for i, group in data_subset_fitnov.groupby("Run_Number"):
    dataz = (group.Exploration_Metric.values)
    plot(range(len(dataz)), dataz, color="red")
    
    
data_subset_fitnov = all_data[all_data.Selection == "Fitnov"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Domain == "Maze"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Final_Fitness > 500]

figure()
for i, group in data_subset_fitnov.groupby("Run_Number"):
    dataz = (group.Cur_Best_Fitness.values)
    plot(range(len(dataz)), dataz, color="blue")
    

data_subset_fitnov = all_data[all_data.Selection == "Fitnov"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Domain == "Maze"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Final_Fitness < 500]

for i, group in data_subset_fitnov.groupby("Run_Number"):
    dataz = (group.Cur_Best_Fitness.values)
    plot(range(len(dataz)), dataz, color="red")
;
# Out:
# ''

# %%
data_subset_fitnov = all_data[all_data.Selection == "Fitnov"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Domain == "Maze"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Final_Fitness > 500]

figure()
for i, group in data_subset_fitnov.groupby("Run_Number"):
    scatter(range(len(group.Exploration_Metric)), group.Exploration_Metric, alpha=0.01)

    
data_subset_fitnov = all_data[all_data.Selection == "Fitnov"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Domain == "Maze"]
data_subset_fitnov = data_subset_fitnov[data_subset_fitnov.Final_Fitness < 500]

figure()
for i, group in data_subset_fitnov.groupby("Run_Number"):
    scatter(range(len(group.Exploration_Metric)), group.Exploration_Metric, alpha=0.01)
;
# Out:
# ''

# %% [markdown]
# # What predicts final fitness better: Early fitness or exploration metric?

# %%
def compare_fitnesses(evaluation, domain, metric):
    data_subset = all_data[all_data.Evaluation == evaluation]
    data_subset = data_subset[data_subset.Domain == domain]
    data_subset_fitness = data_subset[data_subset.Selection == "Fitness"]
    data_subset_fitnov = data_subset[data_subset.Selection == "Fitnov"]
    data_subset_nov = data_subset[data_subset.Selection == "Novelty"]

    sb.jointplot(metric, "Final_Fitness", data=data_subset_fitness, kind="reg", color=sb.color_palette()[0])
    title(domain + " - Fitness")

    sb.jointplot(metric, "Final_Fitness", data=data_subset_fitnov, kind="reg", color=sb.color_palette()[1])
    title(domain + " - Fitnov")

    sb.jointplot(metric, "Final_Fitness", data=data_subset_nov, kind="reg", color=sb.color_palette()[2])
    title(domain + " - Novelty")

# %% [markdown]
# ## Early fitness

# %% [markdown]
# ### Biped

# %% [markdown]
# #### 100 gens, or 50k evaluations

# %%
compare_fitnesses(50000, "Biped", "Cur_Best_Fitness")

# %% [markdown]
# #### 250 gens, or 125k evaluations

# %%
compare_fitnesses(125000, "Biped", "Cur_Best_Fitness")

# %% [markdown]
# #### 500 gens, or 250k evaluations

# %%
compare_fitnesses(250000, "Biped", "Cur_Best_Fitness")

# %% [markdown]
# #### 1000 gens, or 500k evaluations

# %%
compare_fitnesses(500000, "Biped", "Cur_Best_Fitness")

# %% [markdown]
# ### Maze

# %% [markdown]
# #### 100 gens, or 50k evaluations

# %%
compare_fitnesses(50000, "Maze", "Cur_Best_Fitness")

# %% [markdown]
# #### 250 gens, or 125k evaluations

# %%
compare_fitnesses(125000, "Maze", "Cur_Best_Fitness")

# %% [markdown]
# #### 500 gens, or 250k evaluations

# %%
compare_fitnesses(250000, "Maze", "Cur_Best_Fitness")

# %% [markdown]
# #### 1000 gens, or 500k evaluations

# %%
compare_fitnesses(500000, "Maze", "Cur_Best_Fitness")

# %% [markdown]
# ## Early exploration metric

# %% [markdown]
# ### Biped

# %% [markdown]
# #### 100 gens, or 50k evaluations

# %%
compare_fitnesses(50000, "Biped", "Exploration_Metric")

# %% [markdown]
# #### 250 gens, or 125k evaluations

# %%
compare_fitnesses(125000, "Biped", "Exploration_Metric")

# %% [markdown]
# #### 500 gens, or 250k evaluations

# %%
compare_fitnesses(250000, "Biped", "Exploration_Metric")

# %% [markdown]
# #### 1000 gens, or 500k evaluations

# %%
compare_fitnesses(500000, "Biped", "Exploration_Metric")

# %% [markdown]
# ### Maze

# %% [markdown]
# #### 100 gens, or 50k evaluations

# %%
compare_fitnesses(50000, "Maze", "Exploration_Metric")

# %% [markdown]
# #### 250 gens, or 125k evaluations

# %%
compare_fitnesses(125000, "Maze", "Exploration_Metric")

# %% [markdown]
# #### 500 gens, or 250k evaluations

# %%
compare_fitnesses(250000, "Maze", "Exploration_Metric")

# %% [markdown]
# #### 1000 gens, or 500k evaluations

# %%
compare_fitnesses(500000, "Maze", "Exploration_Metric")

# %% [markdown]
# # Data wrangling

# %% [markdown]
# Columns:
#
# * Evaluations so far (i.e. popsize x generation)
#
# * best_fitness_so_far
#
# * N/A
#
# * exploration_metric

# %%
# !head randy-results/biped_fitness_100_log.txt
# Out:
# 500 1.2346 -100000 6167.37
# 1000 1.2346 -100000 6225.38
# 1500 1.39806 -100000 6126.62
# 2000 1.39806 -100000 6119.8
# 2500 1.41934 -100000 6043.78
# 3000 1.45875 -100000 6029.49
# 3500 1.45875 -100000 6010.98
# 4000 1.45875 -100000 6030.41
# 4500 1.49586 -100000 6039.06
# 5000 1.49586 -100000 6097.68

# %%
from glob import glob
from pandas import read_csv, concat

def moving_average(a, n=50):
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

experiment_dfs = []

for i, filename in enumerate(sorted(glob("randy-results/biped_fitness_*.txt"))):
    df = read_csv(filename, sep=" ", names=["Evaluation", "Cur_Best_Fitness", "NA", "Exploration_Metric", "Clock_Time"])
    del df["NA"]
    df["Run_Number"] = i + 1
    df["Domain"] = "Biped"
    df["Selection"] = "Fitness"
    df["Exploration_Metric"] = moving_average(list(df["Exploration_Metric"].values) + list(df["Exploration_Metric"].values)[-49:])
    df["Final_Fitness"] = max(df.Cur_Best_Fitness)
    experiment_dfs.append(df)
    
for i, filename in enumerate(sorted(glob("randy-results/biped_fitnov_*.txt"))):
    df = read_csv(filename, sep=" ", names=["Evaluation", "Cur_Best_Fitness", "NA", "Exploration_Metric", "Clock_Time"])
    del df["NA"]
    df["Run_Number"] = i + 1
    df["Domain"] = "Biped"
    df["Selection"] = "Fitnov"
    df["Exploration_Metric"] = moving_average(list(df["Exploration_Metric"].values) + list(df["Exploration_Metric"].values)[-49:])
    df["Final_Fitness"] = max(df.Cur_Best_Fitness)
    experiment_dfs.append(df)
    
for i, filename in enumerate(sorted(glob("randy-results/biped_novelty_*.txt"))):
    df = read_csv(filename, sep=" ", names=["Evaluation", "Cur_Best_Fitness", "NA", "Exploration_Metric", "Clock_Time"])
    del df["NA"]
    df["Run_Number"] = i + 1
    df["Domain"] = "Biped"
    df["Selection"] = "Novelty"
    df["Exploration_Metric"] = moving_average(list(df["Exploration_Metric"].values) + list(df["Exploration_Metric"].values)[-49:])
    df["Final_Fitness"] = max(df.Cur_Best_Fitness)
    experiment_dfs.append(df)

    
for i, filename in enumerate(sorted(glob("randy-results/maze_fitness_*.txt"))):
    df = read_csv(filename, sep=" ", names=["Evaluation", "Cur_Best_Fitness", "NA", "Exploration_Metric", "Clock_Time"])
    del df["NA"]
    df["Run_Number"] = i + 1
    df["Domain"] = "Maze"
    df["Selection"] = "Fitness"
    df["Exploration_Metric"] = moving_average(list(df["Exploration_Metric"].values) + list(df["Exploration_Metric"].values)[-49:])
    df["Final_Fitness"] = max(df.Cur_Best_Fitness)
    experiment_dfs.append(df)
    
for i, filename in enumerate(sorted(glob("randy-results/maze_fitnov_*.txt"))):
    df = read_csv(filename, sep=" ", names=["Evaluation", "Cur_Best_Fitness", "NA", "Exploration_Metric", "Clock_Time"])
    del df["NA"]
    df["Run_Number"] = i + 1
    df["Domain"] = "Maze"
    df["Selection"] = "Fitnov"
    df["Exploration_Metric"] = moving_average(list(df["Exploration_Metric"].values) + list(df["Exploration_Metric"].values)[-49:])
    df["Final_Fitness"] = max(df.Cur_Best_Fitness)
    experiment_dfs.append(df)
    
for i, filename in enumerate(sorted(glob("randy-results/maze_novelty_*.txt"))):
    df = read_csv(filename, sep=" ", names=["Evaluation", "Cur_Best_Fitness", "NA", "Exploration_Metric", "Clock_Time"])
    del df["NA"]
    df["Run_Number"] = i + 1
    df["Domain"] = "Maze"
    df["Selection"] = "Novelty"
    df["Exploration_Metric"] = moving_average(list(df["Exploration_Metric"].values) + list(df["Exploration_Metric"].values)[-49:])
    df["Final_Fitness"] = max(df.Cur_Best_Fitness)
    experiment_dfs.append(df)
    
all_experiment_df = concat(experiment_dfs)
all_experiment_df.to_csv("randy-results/all_experiments.csv", index=False)
